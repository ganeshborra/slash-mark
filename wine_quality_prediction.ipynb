# %%
pip install pandas numpy matplotlib seaborn scikit-learn

# %%
import pandas as pd

df = pd.read_csv("/content/wine+quality.zip::winequality-red.csv")
print(df.head())
print(df.info())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1752/212777951.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("/content/wine+quality.zip")
#       4 print(df.head())
#       5 print(df.info())
#
# ...
